# %%
import pyforest
from libs.simple_analyzer import print_analytics, print_simple_correlations
from constants import source_path, target_name
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

DATA = pd.read_csv(source_path)

print_analytics(DATA, target_name)
# Out:
# Data Overview:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#
# Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB
# None
#
# Data Info2:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000
#
# Missing data:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64
#
# Features:
#
# Correlations:
# Correlations >= 0.3:
#
# Id:
#
# SepalLengthCm:
#  - Id: 0.72
#
# SepalWidthCm:
#  - Id: -0.40
#
# PetalLengthCm:
#  - Id: 0.88
#  - SepalLengthCm: 0.87
#  - SepalWidthCm: -0.42
#
# PetalWidthCm:
#  - Id: 0.90
#  - SepalLengthCm: 0.82
#  - SepalWidthCm: -0.36
#  - PetalLengthCm: 0.96
# Done

# %%
print_simple_correlations(DATA)
# Out:
# Correlations >= 0.3:
#
# Id:
#
# SepalLengthCm:
#  - Id: 0.72
#
# SepalWidthCm:
#  - Id: -0.40
#
# PetalLengthCm:
#  - Id: 0.88
#  - SepalLengthCm: 0.87
#  - SepalWidthCm: -0.42
#
# PetalWidthCm:
#  - Id: 0.90
#  - SepalLengthCm: 0.82
#  - SepalWidthCm: -0.36
#  - PetalLengthCm: 0.96
# Done

# %%
import mitosheet
mitosheet.sheet(analysis_to_replay="id-ohwxmxnyqe")

# %%
from mitosheet import *
register_analysis("id-ohwxmxnyqe");
    
# Imported X.csv
import pandas as pd
X = pd.read_csv('~/git/machine_learning/kaggle_iris/keras/output/X.csv')

# %%
import streamlit as st
import pandas as pd
import numpy as np
from streamlit import GridOptionsBuilder, AgGrid, GridUpdateMode, DataReturnMode
from constants import source_path, target_name
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

DATA = pd.read_csv(source_path)

# data= pd.read_csv('df_sample_data.csv', index_col=0)
AgGrid(DATA)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [8], in <cell line: 4>()
#       2 import pandas as pd
#       3 import numpy as np
# ----> 4 from streamlit import GridOptionsBuilder, AgGrid, GridUpdateMode, DataReturnMode
#       5 from constants import source_path, target_name
#       6 import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
#
# ImportError: cannot import name 'GridOptionsBuilder' from 'streamlit' (/Users/kkepins-macwro_1/git/machine_learning/env/lib/python3.9/site-packages/streamlit/__init__.py)

# %%
import streamlit as st
import pandas as pd
import numpy as np
from st_aggrid import GridOptionsBuilder, AgGrid, GridUpdateMode, DataReturnMode
from constants import source_path, target_name
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

DATA = pd.read_csv(source_path)

# data= pd.read_csv('df_sample_data.csv', index_col=0)
AgGrid(DATA)

# %%
import lux
from constants import source_path, target_name
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

DATA = pd.read_csv(source_path)
DATA

# %%
import lux
from constants import source_path, target_name
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

DATA = pd.read_csv(source_path)
DATA
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
import sys, imp
imp.reload(sys.modules['KerasModelManager'])
imp.reload(sys.modules['models.models'])
imp.reload(sys.modules['PandasDataManager'])
from constants import target_name, preprocessed_data
from PandasDataManager import PandasDataManager
import pandas as pd

# DATA = pd.read_csv(preprocessed_data)

pdm = PandasDataManager()
X_train, X_valid, y_train, y_valid, Xt, yt = pdm.load_split_train_valid_test(path=preprocessed_data, target_name=target_name, train_perc=0.65, test_perc=0.10
# X_train, X_valid, y_train, y_valid, Xt, yt = pdm.load_split_train_valid_test(path=preprocessed_data, target_name=target_name, train_perc=0.95, test_perc=0.01
                                                                             , train_data_from_beginning=True, rescalex=True, reduce=14)
X_train
# Out:
# array([[ 1.97829199,  0.72191416,  1.02381367, ..., -0.23837003,
#          0.63086777,  0.45597003],
#        [ 2.1710095 ,  0.09019356,  0.32768084, ...,  0.07609456,
#         -0.05571809,  0.59186852],
#        [-1.87765183,  1.10653775,  0.13441388, ...,  0.43617807,
#          0.51670633, -0.39283026],
#        ...,
#        [-0.97186703,  0.74548031,  0.35679466, ...,  0.26806216,
#         -0.08968427,  0.96695308],
#        [ 2.11375532,  0.1536055 ,  0.2539567 , ..., -0.75208054,
#         -0.35777784,  0.57917993],
#        [ 1.34156774,  0.31676701, -0.91388348, ..., -0.66782743,
#         -0.22394367,  0.27841491]])

# %%
import sys, imp
imp.reload(sys.modules['KerasModelManager'])
imp.reload(sys.modules['models.models'])
imp.reload(sys.modules['PandasDataManager'])
from KerasModelManager import KerasModelManager
from models.models import l8_mp2_mp12, l5_mp2, l4_mp, l3_mp, l3, l6_mp2, l2_mp, l7_mp2, l8_mp2\
    , l9_mp4, l5_mp2_k0, l4_mp2_reg, l4_mp_reg, l3_mp2_reg, l4_mp4_reg, l4_mp2_reg_drop, l4_mp2_reg_cust
import tensorflow as tf
from constants import target_name, x_path, y_path, x_test_path, y_test_path, preprocessed_data, x_reduced_path
import matplotlib.pyplot as plt
import matplotlib as mpl
import time

inits = tf.keras.initializers
regs = tf.keras.regularizers
opt = tf.keras.optimizers
tf.random.set_seed(7)
mae_names = []
mae = []

# steps per epoch poszukac
#kiedy stosować RMSE
# batch size vs epoch


features_count = X_train.shape[1]
params = [
    # {'model': l5_mp2_k0(features_count, 1), 'name': 'l5_mp2_k0_mp1'},
    # {'model': l5_mp2_k0(features_count, 2), 'name': 'l5_mp2_k0_mp2'},
    # {'model': l4_mp2_reg(features_count, 1), 'name': 'l4_mp2_reg_mp1'},
    # {'model': l4_mp_reg(features_count, 1), 'name': 'l4_mp_reg_mp1'},
    # {'model': l4_mp_reg(features_count, 2), 'name': 'l4_mp_reg_mp2'},
    # {'model': l3_mp2_reg(features_count, 2), 'name': 'l3_mp2_reg_mp2'},
    # {'model': l4_mp4_reg(features_count, 4, 2), 'name': 'l4_mp4_reg_mp2_2'},
    # {'model': l4_mp4_reg(features_count, 4, 3), 'name': 'l4_mp4_reg_mp2_3'},
    # {'model': l4_mp2_reg(features_count, 4), 'name': 'l4_mp2_reg_mp2'}, #
    # {'model': l4_mp2_reg(features_count, 3), 'name': 'l4_mp2_reg_mp2'}, #
    # {'model': l4_mp2_reg(features_count, 2, 2, kernel_init=tf.keras.initializers.Zeros()), 'name': 'l4_mp2_reg_mp2_zeros'}, #
    # {'model': l4_mp2_reg(features_count, 2, 2, kernel_init=tf.keras.initializers.Ones()), 'name': 'l4_mp2_reg_mp2_ones'}, #
    # {'model': l4_mp2_reg(features_count, 2, 2, kernel_init=tf.keras.initializers.Constant(.1)), 'name': 'l4_mp2_reg_mp2_C01'}, #
    # {'model': l4_mp2_reg(features_count, 2, 2, kernel_init=tf.keras.initializers.GlorotNormal()), 'name': 'l4_mp2_reg_mp2_glorot'}, #
    # {'model': l4_mp2_reg(features_count, 2, 2, kernel_init=tf.keras.initializers.RandomUniform(), bias_init=tf.keras.initializers.Constant(-1)), 'name': 'kernel_ru_bias_c-1'}, #
    # {'model': l4_mp2_reg(features_count, 2, 2, bias_init=tf.keras.initializers.Ones()), 'name': 'l4_mp2_reg_mp2'}, # 141145
    # {'model': l4_mp2_reg(features_count, 2, 2, bias_init=tf.keras.initializers.RandomNormal()), 'name': 'l4_mp2_reg_mp2'}, # 141145
    # {'model': l4_mp2_reg(features_count, 2, 2, kernel_init=tf.keras.initializers.GlorotUniform(seed=8)), 'name': 'kernel_gloruni8'},
    # {'model': l4_mp2_reg(features_count, 2, 2, kernel_init=tf.keras.initializers.GlorotUniform(seed=7), activity_regularizer=tf.keras.regularizers.l2(0.01)), 'name': 'gloruni7_l2'}, #
    # {'model': l4_mp2_reg(features_count, 2, 2, kernel_init=tf.keras.initializers.GlorotUniform(seed=8)), 'name': 'kernel_gloruni8'},
    # {'model': l4_mp2_reg(features_count, 2, 2, kernel_init=tf.keras.initializers.TruncatedNormal(seed=7), activity_regularizer=tf.keras.regularizers.l2(0.01)), 'name': 'kernel_truncn7'}, # 138910
    # # {'model': l4_mp2_reg(features_count, 2, 2, kernel_init=tf.keras.initializers.TruncatedNormal(seed=8)), 'name': 'kernel_truncn8'}, #
    # # {'model': l4_mp2_reg(features_count, 2, 2, kernel_init=tf.keras.initializers.TruncatedNormal(seed=5)), 'name': 'kernel_truncn5'}, # 138609
    # # {'model': l4_mp2_reg(features_count, 2, 2, kernel_init=tf.keras.initializers.RandomUniform(seed=7)), 'name': 'l4_mp2_reg_mp2_kru7'}, #140223
    # {'model': l4_mp2_reg(features_count, 2, 2, kernel_init=tf.keras.initializers.RandomUniform(seed=42), activity_regularizer=tf.keras.regularizers.l2(0.01)), 'name': 'l4_mp2_reg_mp2_kru42'}, #138498
    # # {'model': l4_mp2_reg(features_count, 2, 2, kernel_init=tf.keras.initializers.RandomUniform(seed=52)), 'name': 'l4_mp2_reg_mp2_kru52'}, #138617
    # # {'model': l4_mp2_reg(features_count, 2), 'name': 'l4_mp2_reg_mp2'}, # 139585, 138976, 143943
    # # {'model': l4_mp2_reg(features_count, 3), 'name': 'l4_mp2_reg_mp3'},
    # # {'model': l5_mp2_k0(features_count, 4), 'name': 'l5_mp2_k0_mp4'},
    # # {'model': l5_mp2_k0(features_count, 5), 'name': 'l5_mp2_k0_mp5'},
    # {'model': l4_mp2_reg(features_count, kernel_init=inits.GlorotNormal(seed=7), activity_regularizer=regs.l1(0.002)), 'name': 'glorot002', 'optimizer': opt.Adam()}, #139172
    # {'model': l4_mp2_reg(features_count, kernel_init=inits.GlorotNormal(seed=7), activity_regularizer=regs.l1(0.001)), 'name': 'glorot_l1001_Aeps001', 'optimizer': opt.Adam(epsilon=0.001)},#145
    # {'model': l4_mp2_reg(features_count, kernel_init=inits.GlorotNormal(seed=7), activity_regularizer=regs.l1(0.001)), 'name': 'glorot_l1001_Alr005', 'optimizer': opt.Adam(learning_rate=0.005)},
    # {'model': l4_mp2_reg(features_count, kernel_init=inits.GlorotNormal(seed=7), activity_regularizer=regs.l1(0.005)), 'name': 'glorot_l1005', 'optimizer': opt.Adam()}, #139350
    # {'model': l4_mp2_reg(features_count, kernel_init=inits.GlorotNormal(seed=7), activity_regularizer=regs.l1(0.001)), 'name': 'glorot_l1001_lr0005', 'optimizer': opt.Adam(learning_rate=0.0005)}, #
    # {'model': l4_mp2_reg(features_count, kernel_init=inits.GlorotNormal(seed=7), activity_regularizer=regs.l1(0.001)), 'name': 'glorot_l1001_amsgrad', 'optimizer': opt.Adam(amsgrad=True)}, #
    # {'model': l4_mp2_reg(features_count, kernel_init=inits.GlorotNormal(seed=7), activity_regularizer=regs.l1(0.0005)), 'name': 'glorot_l10005', 'optimizer': opt.Adam()}, #138700
    # {'model': l4_mp2_reg(features_count, kernel_init=inits.GlorotNormal(seed=7), activity_regularizer=regs.l1(0.0001)), 'name': 'glorot_l10001', 'optimizer': opt.Adam()}, #138700
    # {'model': l4_mp2_reg(features_count, kernel_init=tf.keras.initializers.GlorotNormal(seed=7), activity_regularizer=tf.keras.regularizers.l1(0.01)), 'name': 'glorot_nomr01'}, #
    # {'model': l4_mp2_reg(features_count, kernel_init=tf.keras.initializers.GlorotNormal(seed=7), activity_regularizer=tf.keras.regularizers.l1(0.03)), 'name': 'glorot_nomr03'}, #
    # {'model': l4_mp2_reg(features_count, kernel_init=tf.keras.initializers.GlorotNormal(seed=7), activity_regularizer=tf.keras.regularizers.l1(0.05)), 'name': 'glorot_nomr05'}, #
    # {'model': l4_mp2_reg(features_count, kernel_init=tf.keras.initializers.GlorotUniform(seed=7), activity_regularizer=tf.keras.regularizers.l1(0.01)), 'name': 'glorot_uni01'}, #138248
    # {'model': l4_mp2_reg(features_count, kernel_init=tf.keras.initializers.GlorotUniform(seed=7), activity_regularizer=tf.keras.regularizers.l1(0.05)), 'name': 'glorot_uni05'}, #
    # {'model': l4_mp2_reg(features_count, kernel_init=inits.GlorotNormal(seed=7), activity_regularizer=regs.l1(0.001)), 'name': 'glorot_b6', 'optimizer': opt.Adam(), 'batch': 256-64, 'epochs':40},
    # {'model': l4_mp2_reg(features_count, kernel_init=inits.GlorotNormal(seed=7), activity_regularizer=regs.l1(0.001)), 'name': 'glorot_b5', 'optimizer': opt.Adam(), 'batch': 256, 'epochs':50},
    # {'model': l4_mp2_reg(features_count, kernel_init=inits.GlorotNormal(seed=7), activity_regularizer=regs.l1(0.001)), 'name': 'glorot_b4', 'optimizer': opt.Adam(), 'batch': 256+64, 'epochs':60},
    # {'model': l4_mp2_reg(features_count, kernel_init=inits.GlorotNormal(seed=7), activity_regularizer=regs.l1(0.001)), 'name': 'glorot_b2', 'optimizer': opt.Adam(), 'batch': 512+256, 'epochs':150},
    # {'model': l4_mp2_reg(features_count, kernel_init=inits.GlorotNormal(seed=7), activity_regularizer=regs.l1(0.001)), 'name': 'glorot_b1', 'optimizer': opt.Adam(), 'batch': 512+128, 'epochs':125},
    # {'model': l4_mp2_reg(features_count, kernel_init=inits.GlorotNormal(seed=7), activity_regularizer=regs.l1(0.001)), 'name': 'glorot', 'optimizer': opt.Adam(), 'batch': 512, 'epochs': 100}, #138700, 179432, 137541
    # {'model': l4_mp2_reg(features_count, kernel_init=inits.GlorotNormal(seed=7), activity_regularizer=regs.l1(0.001)), 'name': 'glorot_l1001_b1_08', 'optimizer': opt.Adam(beta_1=0.8), 'batch': 512}, #138104
    # {'model': l4_mp2_reg(features_count, kernel_init=inits.GlorotNormal(seed=7), activity_regularizer=regs.l1(0.001)), 'name': 'glorot_l1001_b1_07', 'optimizer': opt.Adam(beta_1=0.7), 'batch': 512}, #139213
    # {'model': l4_mp2_reg(features_count, kernel_init=inits.GlorotNormal(seed=7), activity_regularizer=regs.l1(0.001)), 'name': 'glorot_l1001_b105_b208', 'optimizer': opt.Adam(beta_1=0.5, beta_2=0.8)}, #
    # {'model': l4_mp2_reg(features_count, kernel_init=inits.GlorotNormal(seed=7), activity_regularizer=regs.l1(0.001)), 'name': 'glorot_l1001_b1_05', 'optimizer': opt.Adam(beta_1=0.5)}, #
    # {'model': l8_mp2(features_count, 4), 'name': 'l8_mp2_4', 'optimizer': opt.Adam()},#188504
    # {'model': l4_mp2_reg_drop(features_count, dropout=0.6), 'name': 'glorot_drop06', 'optimizer': opt.Adam(), 'batch': 256+128, 'epochs':75},
    # {'model': l4_mp2_reg_drop(features_count, dropout=0.3), 'name': 'glorot_drop03', 'optimizer': opt.Adam(), 'batch': 256+128, 'epochs':75}, #140897
    # {'model': l4_mp2_reg_drop(features_count, dropout=0.2), 'name': 'glorot_drop02', 'optimizer': opt.Adam(), 'batch': 256+128, 'epochs':75},
    # {'model': l4_mp2_reg_drop(features_count, dropout=0.1), 'name': 'glorot_drop01', 'optimizer': opt.Adam(), 'batch': 256+128, 'epochs':75},
    # {'model': l4_mp2_reg_cust(18, kernel_init=inits.GlorotNormal(seed=7), activity_regularizer=regs.l1(0.001)), 'name': 'glorot_cust', 'optimizer': opt.Adam(), 'batch': 256+128, 'epochs':75},
    # {'model': l4_mp2_reg(18), 'name': 'glorot_b3_red13', 'optimizer': opt.Adam(), 'batch': 256+128, 'epochs':75, 'reduce': 5},
    # {'model': l4_mp2_reg(18), 'name': 'glorot_b3_red15', 'optimizer': opt.Adam(), 'batch': 256+128, 'epochs':75, 'reduce': 3},
    # {'model': l4_mp2_reg(18), 'name': 'glorot_b3', 'optimizer': opt.Adam(), 'batch': 256+128, 'epochs':75, 'reduce':None},
    # {'model': l4_mp2_reg(32), 'name': 'glorot_b3', 'optimizer': opt.Adam(), 'batch': 256+128, 'epochs':75, 'reduce':None},
    # {'model': l4_mp2_reg(64), 'name': 'glorot_b3', 'optimizer': opt.Adam(), 'batch': 256+128, 'epochs':75, 'reduce':None},
    # {'model': l4_mp2_reg(128), 'name': 'glorot_b3', 'optimizer': opt.Adam(), 'batch': 256+128, 'epochs':75, 'reduce':None},
    # {'model': l4_mp2_reg(288, 2, 2), 'name': 'glorot_u1', 'optimizer': opt.Adam(), 'batch': 256+128, 'epochs':75},
    # {'model': l4_mp2_reg(288, 4, 2), 'name': 'glorot_u2', 'optimizer': opt.Adam(), 'batch': 256+128, 'epochs':75},
    # {'model': l4_mp2_reg(288, 10, 4), 'name': 'glorot_u3', 'optimizer': opt.Adam(), 'batch': 256+128, 'epochs':75},
    # {'model': l4_mp2_reg(288, 10, 8), 'name': 'glorot_u3', 'optimizer': opt.Adam(), 'batch': 256+128, 'epochs':75},
    # {'model': l4_mp2_reg(288, 8, 2), 'name': 'glorot', 'optimizer': opt.Adam(), 'batch': 256+128, 'epochs':75},
    # {'model': l4_mp2_reg(288), 'name': 'glorot', 'optimizer': opt.Adam(), 'batch': 256+128, 'epochs':75},
    # {'model': l4_mp2_reg(288, 6, 2), 'name': 'glorot_mp10', 'optimizer': opt.Adam(), 'batch': 128, 'epochs':100},
    # {'model': l4_mp2_reg(288, 6, 2), 'name': 'glorot_mp10', 'optimizer': opt.Adam(), 'batch': 256, 'epochs':100},
    # {'model': l4_mp2_reg(288, 6, 2), 'name': 'glorot_mp10', 'optimizer': opt.Adam(), 'batch': 256, 'epochs':60},
    # {'model': l4_mp2_reg(288, 6, 2), 'name': 'glorot_mp10', 'optimizer': opt.Adam(), 'batch': 256, 'epochs':80},
    # {'model': l4_mp2_reg(288, 6, 2), 'name': 'glorot_mp10', 'optimizer': opt.Adam(), 'batch': 128, 'epochs':100},
    # {'model': l4_mp2_reg(288, 6, 2), 'name': 'glorot_mp10', 'optimizer': opt.Adam(), 'batch': 128, 'epochs':150},
    # {'model': l4_mp2_reg(288, 6, 2), 'name': 'glorot_mp10', 'optimizer': opt.Adam(), 'batch': 256, 'epochs':150},
    # {'model': l4_mp2_reg(288, 6, 2), 'name': 'glorot_mp10', 'optimizer': opt.Adam(), 'batch': 256, 'epochs':200},
    # {'model': l4_mp2_reg(288, 6, 2), 'name': 'glorot_mp10', 'optimizer': opt.Adam(), 'batch': 512+256, 'epochs':100},
    # {'model': l4_mp2_reg(288, 6, 2), 'name': 'glorot_mp10', 'optimizer': opt.Adam(), 'batch': 1024, 'epochs':100},
    # {'model': l4_mp2_reg(288, 15, 2), 'name': 'glorot_mp15', 'optimizer': opt.Adam(), 'batch': 256+128, 'epochs':75},
    # {'model': l4_mp2_reg(288, 20, 2), 'name': 'glorot_mp20', 'optimizer': opt.Adam(), 'batch': 256+128, 'epochs':75},
    # {'model': l4_mp2_reg(288, 6, 2), 'name': 'glorot_mp10', 'optimizer': opt.Adam(), 'batch': 256, 'epochs':100, 'steps_per_epoch': 5},
    # {'model': l4_mp2_reg(288, 6, 2), 'name': 'glorot_mp10', 'optimizer': opt.Adam(), 'batch': 256, 'epochs':100, 'steps_per_epoch': 10},
    # {'model': l4_mp2_reg(288, 6, 2), 'name': 'glorot_mp10', 'optimizer': opt.Adam(), 'batch': 256, 'epochs':100, 'steps_per_epoch': 8},
    # {'model': l4_mp2_reg(288, 6, 2), 'name': 'glorot_mp10', 'optimizer': opt.Adam(), 'batch': 256, 'epochs':120, 'steps_per_epoch': 11},
    # {'model': l4_mp2_reg(288, 6, 2), 'name': 'glorot_mp10', 'optimizer': opt.Adam(), 'batch': 256, 'epochs':140, 'steps_per_epoch': 12},
    # {'model': l4_mp2_reg(288, 6, 2), 'name': 'glorot_mp10', 'optimizer': opt.Adam(), 'batch': 256, 'epochs':160, 'steps_per_epoch': 14},
    # {'model': l4_mp2_reg(288, 6, 2), 'name': 'glorot_mp10', 'optimizer': opt.Adam(), 'batch': 128, 'epochs':160, 'steps_per_epoch': 16},
    # {'model': l4_mp2_reg(288, 6, 2), 'name': 'glorot_mp10', 'optimizer': opt.Adam(), 'batch': 128, 'epochs':160, 'steps_per_epoch': 18},
    # {'model': l4_mp2_reg(512, features_count, 6, 2), 'name': 'glorot_mp10', 'batch': 256, 'epochs':100, 'steps_per_epoch': None},
    # {'model': l4_mp2_reg(512+128, features_count, 6, 2), 'name': 'glorot_mp10', 'batch': 256, 'epochs':100, 'steps_per_epoch': None},
    {'model': l4_mp2_reg(1024, features_count, 6, 2), 'name': 'glorot_mp10', 'batch': 256, 'epochs':100, 'steps_per_epoch': int(X_train.shape[0]/256), 'val_batch': 32, 'val_steps': int(X_valid.shape[0]/32)},
    {'model': l4_mp2_reg(1024, features_count, 6, 2), 'name': 'glorot_mp10', 'batch': 256, 'epochs':100, 'steps_per_epoch': int(X_train.shape[0]/256), 'val_batch': None, 'val_steps': None},
    # {'model': l4_mp2_reg(1024+512, features_count, 6, 2), 'name': 'glorot_mp10', 'batch': 256, 'epochs':100, 'steps_per_epoch': None},
    # {'model': l4_mp2_reg(2048, features_count, 6, 2), 'name': 'glorot_mp10', 'batch': 256, 'epochs':100, 'steps_per_epoch': None},
    # {'model': l4_mp2_reg(288, features_count, 6, 2), 'name': 'glorot_mp10', 'batch': 256, 'epochs':100, 'steps_per_epoch': None},
]


for p in params:
    # print(p['model'].layers)
    start_time = time.time()

    km = KerasModelManager(p['model'])
    km.compile_fit(X_train, y_train, X_valid, y_valid
                   , batch_size=p['batch']
                   , epochs=p['epochs']
                   , optimizer=opt.Adam()
                   , loss='mse'
                   , steps_per_epoch=p['steps_per_epoch']
                   , validation_steps=p['val_steps']
                   , validation_batch_size=p['val_batch']
                   , verbose=1)

    # km.plot_training_history()
    res = km.predict(Xt, yt)
    km.plot_predictions()
    mae.append(res['mae'])
    mae_names.append(p['name'])
    print('\n> Model:', p['name'])
    print("- MAE: ", res['mae'])
    print("- MAE %: ", res['mape'])
    print("- RMSE: ", res['rmse'])
    print(" [time secs: ", (time.time() - start_time), "]")

print("DONE.")
# Out:
# Epoch 1/100
# 2023-01-20 20:07:43.264640: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 3/3 [==============================] - ETA: 0s - loss: 179561.4375 - mean_absolute_error: 179558.8750
# 2023-01-20 20:07:44.936744: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 3/3 [==============================] - 3s 600ms/step - loss: 179561.4375 - mean_absolute_error: 179558.8750 - val_loss: 184634.2656 - val_mean_absolute_error: 184620.7969
# Epoch 2/100
# 3/3 [==============================] - 1s 493ms/step - loss: 176707.4219 - mean_absolute_error: 176675.9062 - val_loss: 183785.6406 - val_mean_absolute_error: 183718.0312
# Epoch 3/100
# 3/3 [==============================] - 1s 424ms/step - loss: 181328.0312 - mean_absolute_error: 181223.9375 - val_loss: 181482.0469 - val_mean_absolute_error: 181294.1406
# Epoch 4/100
# ...

# %%
style = dict(size=15, color='black')
mpl.style.use('seaborn-v0_8')
fig, ax = plt.subplots(figsize=(15, 7))
ax.set_title("MAE for models", color='C0')
for i in range(len(mae)):
    ax.text(i, mae[i], mae_names[i], **style)
ax.plot(range(len(mae)), mae, color="#00f", label="mae")
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 style = dict(size=15, color='black')
# ----> 2 mpl.style.use('seaborn-v0_8')
#       3 fig, ax = plt.subplots(figsize=(15, 7))
#       4 ax.set_title("MAE for models", color='C0')
#
# NameError: name 'mpl' is not defined

# %%
style = dict(size=15, color='black')
mpl.style.use('seaborn-v0_8')
fig, ax = plt.subplots(figsize=(15, 7))
ax.set_title("MAE for models", color='C0')
for i in range(len(mae)):
    ax.text(i, mae[i], mae_names[i], **style)
ax.plot(range(len(mae)), mae, color="#00f", label="mae")
plt.legend()

# %%
pdm.X_train

# %%
from libs.simple_analyzer import simple_correlations, print_simple_correlations, simple_heatmap
from constants import preprocessed_data, target_name, x_path, y_path
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

DATA = pd.read_csv(preprocessed_data)

simple_heatmap(DATA)

# %%
from libs.simple_processing import separate_target, scale
import pandas as pd
from constants import preprocessed_data

df = pd.read_csv(preprocessed_data)

scaled = scale(df)

length = int(len(scaled) * 0.99)
TEST = scaled[length:]
DATA = scaled[:length]

DATA
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      0.019266  0.090909    0.12500     0.067170  0.003108     0.0
# 1      0.060721  0.090909    0.28125     0.172075  0.004072     0.4
# 2      0.013770  0.060606    0.12500     0.036226  0.005743     0.0
# 3      0.069377  0.121212    0.37500     0.126038  0.002714     0.0
# 4      0.057049  0.090909    0.25000     0.104906  0.004579     0.0
# ...         ...       ...        ...          ...       ...     ...
# 21391  0.025567  0.090909    0.31250     0.147472  0.002156     0.4
# 21392  0.037115  0.090909    0.31250     0.131019  0.004295     0.4
# 21393  0.036066  0.090909    0.31250     0.108679  0.002160     0.4
# 21394  0.092721  0.121212    0.43750     0.273208  0.004589     0.4
# 21395  0.092328  0.090909    0.31250     0.097358  0.000586     0.8
#
#        waterfront  view  condition     grade  sqft_above  sqft_basement  \
# 0             0.0  0.00        0.5  0.500000    0.097588       0.000000
# ...

# %%
from constants import target_name, x_path, y_path, x_test_path, y_test_path

X, y = separate_target(DATA, target_name)
Xt, yt = separate_target(TEST, target_name)

X.to_csv(x_path, index=False)
y.to_csv(y_path, index=False)
Xt.to_csv(x_test_path, index=False)
yt.to_csv(y_test_path, index=False)

Xt
# Out:
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 21396  0.121212    0.31250     0.167547  0.001792     0.4         0.0   0.0
# 21397  0.060606    0.28125     0.053585  0.000233     0.8         0.0   0.0
# 21398  0.121212    0.31250     0.103396  0.001199     0.4         0.0   0.0
# 21399  0.121212    0.43750     0.209057  0.002455     0.4         0.0   0.0
# 21400  0.090909    0.31250     0.127547  0.002411     0.4         0.0   0.0
# ...         ...        ...          ...       ...     ...         ...   ...
# 21608  0.090909    0.31250     0.093585  0.000370     0.8         0.0   0.0
# 21609  0.121212    0.31250     0.152453  0.003206     0.4         0.0   0.0
# 21610  0.060606    0.09375     0.055094  0.000503     0.4         0.0   0.0
# 21611  0.090909    0.31250     0.098868  0.001132     0.4         0.0   0.0
# 21612  0.060606    0.09375     0.055094  0.000337     0.4         0.0   0.0
#
# ...

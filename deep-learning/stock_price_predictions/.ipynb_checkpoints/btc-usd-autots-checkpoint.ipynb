# %%
import pandas as pd
import logging, time, datetime
from autots import AutoTS
import matplotlib.pyplot as plt
from dslibs.simple_yahoo import get_from_yahoo

logging.getLogger('autots').setLevel(logging.ERROR)

df = get_from_yahoo('BTC-USD', '2021-01-01', '2023-04-13')
df
# Out:
# Done
#            Date          Open          High           Low         Close  \
# 0    2020-12-31  28841.574219  29244.876953  28201.992188  29001.720703
# 1    2021-01-01  28994.009766  29600.626953  28803.585938  29374.152344
# 2    2021-01-02  29376.455078  33155.117188  29091.181641  32127.267578
# 3    2021-01-03  32129.408203  34608.558594  32052.316406  32782.023438
# 4    2021-01-04  32810.949219  33440.218750  28722.755859  31971.914063
# ..          ...           ...           ...           ...           ...
# 828  2023-04-08  27920.513672  28159.863281  27883.386719  27947.794922
# 829  2023-04-09  27952.367188  28532.830078  27828.480469  28333.050781
# 830  2023-04-10  28336.027344  29771.464844  28189.271484  29652.980469
# 831  2023-04-11  29653.679688  30509.083984  29609.300781  30235.058594
# 832  2023-04-12  30231.582031  30462.480469  29725.574219  30139.052734
#
#         Adj Close       Volume
# 0    29001.720703  46754964848
# 1    29374.152344  40730301359
# ...

# %%
import logging
import joblib
import time
import datetime

logging.getLogger('autots').setLevel(logging.ERROR)

start = time.time()
model = AutoTS(forecast_length=7, frequency='D', prediction_interval=1, ensemble='simple', random_seed=42, verbose=0)
model.fit(df, date_col='Date', value_col='Close')
print('Time[min]: ' + str((time.time() - start)/60))

current_time = time.time()
datetime_obj = datetime.datetime.fromtimestamp(current_time)
datetime_str = datetime_obj.strftime('%Y-%m-%d-%H-%M-%S')
filename = "btc-usd-AutoTS-"+datetime_str+".joblib"
joblib.dump(model, filename)

print("Model saved.")
# Out:
# Template Eval Error: Exception('Transformer QuantileTransformer failed on inverse') in model 5: DatepartRegression
# Template Eval Error: Exception('Transformer QuantileTransformer failed on inverse') in model 6: DatepartRegression
# Template Eval Error: Exception('Transformer QuantileTransformer failed on inverse') in model 7: DatepartRegression
# Metal device set to: Apple M1
# 2023-04-14 06:48:25.066197: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-04-14 06:48:25.066488: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# ...

# %%
                # Wyświetlenie prognozy
# prediction = model.predict()#date_col='Date', value_col='Close')#test_data, )
prediction = model.predict(forecast_length=14)#date_col='Date', value_col='Close')#test_data, )
forecast = prediction.forecast
print("============= PROGNOZA ===================")
print(forecast)
print("==========================================")

# forecast.index
# df
# Out:
# ============= PROGNOZA ===================
#                    Close
# 2023-04-13  29689.953052
# 2023-04-14  30159.773317
# 2023-04-15  30401.225576
# 2023-04-16  30657.115816
# 2023-04-17  30820.119627
# 2023-04-18  31009.516753
# 2023-04-19  31198.915716
# 2023-04-20  31308.791004
# 2023-04-21  31510.427282
# 2023-04-22  31711.680399
# 2023-04-23  31928.155397
# 2023-04-24  32123.351287
# 2023-04-25  32328.303056
# 2023-04-26  32576.546290
# ...

# %%
from dslibs.simple_yahoo import get_from_yahoo

real = get_from_yahoo('BTC-USD', '2023-03-25', '2023-04-02')
real
# Out:
# Done
#          Date          Open          High           Low         Close  \
# 0  2023-03-24  28324.111328  28388.437500  27039.265625  27493.285156
# 1  2023-03-25  27487.337891  27791.826172  27196.234375  27494.707031
# 2  2023-03-26  27495.523438  28178.144531  27445.046875  27994.330078
# 3  2023-03-27  27994.068359  28037.925781  26606.689453  27139.888672
# 4  2023-03-28  27132.888672  27460.718750  26677.818359  27268.130859
# 5  2023-03-29  27284.833984  28601.423828  27259.662109  28343.531250
#
#       Adj Close       Volume
# 0  27493.285156  25980310960
# 1  27494.707031  13383005987
# 2  27994.330078  13878363192
# 3  27139.888672  18188895178
# 4  27268.130859  17783600385
# 5  28343.531250  21012973568

# %%
import joblib
import time
import datetime

# Pobranie aktualnego czasu w sekundach
current_time = time.time()

# Konwersja na typ datetime.datetime
datetime_obj = datetime.datetime.fromtimestamp(current_time)

# Konwersja na string z formatem YYYY-MM-DD HH:MM:SS
datetime_str = datetime_obj.strftime('%Y-%m-%d-%H-%M-%S')

# filename = "btc-usd-AutoTS-mae"+str(int(mae))+"-"+datetime_str+".joblib"
filename = "btc-usd-AutoTS-"+datetime_str+".joblib"

joblib.dump(model, filename)

print("Model saved.")
# Out:
# Model saved.

# %%
import joblib

filename = "btc-usd-AutoTS-2023-03-28-19-56-58.joblib"

model1 = joblib.load(filename)
prediction = model1.predict()
forecast = prediction.forecast
print(forecast)
print(model1.best_model_name)
# Out:
# /Users/kkepins-macwro_1/.local/share/virtualenvs/ml-IYlnPhoE/lib/python3.10/site-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/kkepins-macwro_1/.local/share/virtualenvs/ml-IYlnPhoE/lib/python3.10/site-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/kkepins-macwro_1/.local/share/virtualenvs/ml-IYlnPhoE/lib/python3.10/site-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/kkepins-macwro_1/.local/share/virtualenvs/ml-IYlnPhoE/lib/python3.10/site-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# ...

# %%
print(model1.best_model_name)
print(model1.best_model_params)
# Out:
# Ensemble
# ...

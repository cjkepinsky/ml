# %%
# !pip install --upgrade langchain deeplake openai tiktoken
# !pip install openai
# Out:
# Collecting langchain
#   Downloading langchain-0.1.16-py3-none-any.whl.metadata (13 kB)
# Collecting deeplake
#   Downloading deeplake-3.9.1.tar.gz (589 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 589.7/589.7 kB 7.5 MB/s eta 0:00:004.9 MB/s eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting openai
#   Downloading openai-1.23.6-py3-none-any.whl.metadata (21 kB)
# Collecting tiktoken
#   Downloading tiktoken-0.6.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Requirement already satisfied: PyYAML>=5.3 in /Users/krzysztof/.local/share/virtualenvs/ml-uTCkY2ki/lib/python3.10/site-packages (from langchain) (6.0.1)
# Collecting SQLAlchemy<3,>=1.4 (from langchain)
#   Downloading SQLAlchemy-2.0.29-cp310-cp310-macosx_11_0_arm64.whl.metadata (9.6 kB)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain)
#   Downloading aiohttp-3.9.5-cp310-cp310-macosx_11_0_arm64.whl.metadata (7.5 kB)
# Collecting async-timeout<5.0.0,>=4.0.0 (from langchain)
#   Downloading async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain)
#   Downloading dataclasses_json-0.6.4-py3-none-any.whl.metadata (25 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langchain-community<0.1,>=0.0.32 (from langchain)
#   Downloading langchain_community-0.0.34-py3-none-any.whl.metadata (8.5 kB)
# Collecting langchain-core<0.2.0,>=0.1.42 (from langchain)
#   Downloading langchain_core-0.1.46-py3-none-any.whl.metadata (5.9 kB)
# Collecting langchain-text-splitters<0.1,>=0.0.1 (from langchain)
#   Downloading langchain_text_splitters-0.0.1-py3-none-any.whl.metadata (2.0 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain)
#   Downloading langsmith-0.1.51-py3-none-any.whl.metadata (13 kB)
# Collecting numpy<2,>=1 (from langchain)
#   Downloading numpy-1.26.4-cp310-cp310-macosx_11_0_arm64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 9.2 MB/s eta 0:00:00
# Collecting pydantic<3,>=1 (from langchain)
#   Downloading pydantic-2.7.1-py3-none-any.whl.metadata (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.3/107.3 kB 16.2 MB/s eta 0:00:00
# Requirement already satisfied: requests<3,>=2 in /Users/krzysztof/.local/share/virtualenvs/ml-uTCkY2ki/lib/python3.10/site-packages (from langchain) (2.31.0)
# Collecting tenacity<9.0.0,>=8.1.0 (from langchain)
#   Downloading tenacity-8.2.3-py3-none-any.whl.metadata (1.0 kB)
# Collecting pillow~=10.2.0 (from deeplake)
#   Downloading pillow-10.2.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (9.7 kB)
# Collecting boto3 (from deeplake)
#   Downloading boto3-1.34.92-py3-none-any.whl.metadata (6.6 kB)
# Collecting click (from deeplake)
#   Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting pathos (from deeplake)
#   Downloading pathos-0.3.2-py3-none-any.whl.metadata (11 kB)
# Collecting humbug>=0.3.1 (from deeplake)
#   Downloading humbug-0.3.2-py3-none-any.whl.metadata (6.8 kB)
# Collecting tqdm (from deeplake)
#   Downloading tqdm-4.66.2-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 7.0 MB/s eta 0:00:00
# Collecting lz4 (from deeplake)
#   Downloading lz4-4.3.3-cp310-cp310-macosx_11_0_arm64.whl.metadata (3.7 kB)
# Collecting pyjwt (from deeplake)
#   Downloading PyJWT-2.8.0-py3-none-any.whl.metadata (4.2 kB)
# Collecting libdeeplake==0.0.119 (from deeplake)
#   Downloading libdeeplake-0.0.119-cp310-cp310-macosx_11_0_arm64.whl.metadata (347 bytes)
# Collecting aioboto3>=10.4.0 (from deeplake)
#   Downloading aioboto3-12.4.0-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: nest-asyncio in /Users/krzysztof/.local/share/virtualenvs/ml-uTCkY2ki/lib/python3.10/site-packages (from deeplake) (1.6.0)
# Collecting dill (from libdeeplake==0.0.119->deeplake)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/krzysztof/.local/share/virtualenvs/ml-uTCkY2ki/lib/python3.10/site-packages (from openai) (4.3.0)
# Collecting distro<2,>=1.7.0 (from openai)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/krzysztof/.local/share/virtualenvs/ml-uTCkY2ki/lib/python3.10/site-packages (from openai) (0.27.0)
# Requirement already satisfied: sniffio in /Users/krzysztof/.local/share/virtualenvs/ml-uTCkY2ki/lib/python3.10/site-packages (from openai) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /Users/krzysztof/.local/share/virtualenvs/ml-uTCkY2ki/lib/python3.10/site-packages (from openai) (4.11.0)
# Collecting regex>=2022.1.18 (from tiktoken)
#   Downloading regex-2024.4.16-cp310-cp310-macosx_11_0_arm64.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 5.7 MB/s eta 0:00:00
# Collecting aiobotocore==2.12.3 (from aiobotocore[boto3]==2.12.3->aioboto3>=10.4.0->deeplake)
#   Downloading aiobotocore-2.12.3-py3-none-any.whl.metadata (21 kB)
# Collecting botocore<1.34.70,>=1.34.41 (from aiobotocore==2.12.3->aiobotocore[boto3]==2.12.3->aioboto3>=10.4.0->deeplake)
#   Downloading botocore-1.34.69-py3-none-any.whl.metadata (5.7 kB)
# Collecting wrapt<2.0.0,>=1.10.10 (from aiobotocore==2.12.3->aiobotocore[boto3]==2.12.3->aioboto3>=10.4.0->deeplake)
#   Downloading wrapt-1.16.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Collecting aioitertools<1.0.0,>=0.5.1 (from aiobotocore==2.12.3->aiobotocore[boto3]==2.12.3->aioboto3>=10.4.0->deeplake)
#   Downloading aioitertools-0.11.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting boto3 (from deeplake)
#   Downloading boto3-1.34.69-py3-none-any.whl.metadata (6.6 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs>=17.3.0 in /Users/krzysztof/.local/share/virtualenvs/ml-uTCkY2ki/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading frozenlist-1.4.1-cp310-cp310-macosx_11_0_arm64.whl.metadata (12 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading multidict-6.0.5-cp310-cp310-macosx_11_0_arm64.whl.metadata (4.2 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading yarl-1.9.4-cp310-cp310-macosx_11_0_arm64.whl.metadata (31 kB)
# Requirement already satisfied: idna>=2.8 in /Users/krzysztof/.local/share/virtualenvs/ml-uTCkY2ki/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/krzysztof/.local/share/virtualenvs/ml-uTCkY2ki/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (1.2.1)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3->deeplake)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.11.0,>=0.10.0 (from boto3->deeplake)
#   Downloading s3transfer-0.10.1-py3-none-any.whl.metadata (1.7 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain)
#   Downloading marshmallow-3.21.1-py3-none-any.whl.metadata (7.2 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: certifi in /Users/krzysztof/.local/share/virtualenvs/ml-uTCkY2ki/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /Users/krzysztof/.local/share/virtualenvs/ml-uTCkY2ki/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/krzysztof/.local/share/virtualenvs/ml-uTCkY2ki/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/krzysztof/.local/share/virtualenvs/ml-uTCkY2ki/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain) (2.4)
# Collecting packaging<24.0,>=23.2 (from langchain-core<0.2.0,>=0.1.42->langchain)
#   Downloading packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.17->langchain)
#   Downloading orjson-3.10.1-cp310-cp310-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl.metadata (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 7.2 MB/s eta 0:00:00
# Collecting annotated-types>=0.4.0 (from pydantic<3,>=1->langchain)
#   Downloading annotated_types-0.6.0-py3-none-any.whl.metadata (12 kB)
# Collecting pydantic-core==2.18.2 (from pydantic<3,>=1->langchain)
#   Downloading pydantic_core-2.18.2-cp310-cp310-macosx_11_0_arm64.whl.metadata (6.5 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/krzysztof/.local/share/virtualenvs/ml-uTCkY2ki/lib/python3.10/site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/krzysztof/.local/share/virtualenvs/ml-uTCkY2ki/lib/python3.10/site-packages (from requests<3,>=2->langchain) (2.2.1)
# Collecting ppft>=1.7.6.8 (from pathos->deeplake)
#   Downloading ppft-1.7.6.8-py3-none-any.whl.metadata (12 kB)
# Collecting pox>=0.3.4 (from pathos->deeplake)
#   Downloading pox-0.3.4-py3-none-any.whl.metadata (8.0 kB)
# Collecting multiprocess>=0.70.16 (from pathos->deeplake)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /Users/krzysztof/.local/share/virtualenvs/ml-uTCkY2ki/lib/python3.10/site-packages (from botocore<1.34.70,>=1.34.41->aiobotocore==2.12.3->aiobotocore[boto3]==2.12.3->aioboto3>=10.4.0->deeplake) (2.9.0.post0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: six>=1.5 in /Users/krzysztof/.local/share/virtualenvs/ml-uTCkY2ki/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.34.70,>=1.34.41->aiobotocore==2.12.3->aiobotocore[boto3]==2.12.3->aioboto3>=10.4.0->deeplake) (1.16.0)
# Downloading langchain-0.1.16-py3-none-any.whl (817 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 817.7/817.7 kB 32.6 MB/s eta 0:00:00
# Downloading libdeeplake-0.0.119-cp310-cp310-macosx_11_0_arm64.whl (10.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.6/10.6 MB 78.2 MB/s eta 0:00:00MB/s eta 0:00:01:01
# Downloading openai-1.23.6-py3-none-any.whl (311 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.6/311.6 kB 42.7 MB/s eta 0:00:00
# Downloading tiktoken-0.6.0-cp310-cp310-macosx_11_0_arm64.whl (949 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 950.0/950.0 kB 63.3 MB/s eta 0:00:00
# Downloading aioboto3-12.4.0-py3-none-any.whl (32 kB)
# Downloading aiobotocore-2.12.3-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 9.5 MB/s eta 0:00:00
# Downloading aiohttp-3.9.5-cp310-cp310-macosx_11_0_arm64.whl (389 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 389.9/389.9 kB 45.8 MB/s eta 0:00:00
# Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Downloading boto3-1.34.69-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 17.9 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.4-py3-none-any.whl (28 kB)
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading humbug-0.3.2-py3-none-any.whl (15 kB)
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langchain_community-0.0.34-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 59.4 MB/s eta 0:00:00
# Downloading langchain_core-0.1.46-py3-none-any.whl (299 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 299.3/299.3 kB 25.3 MB/s eta 0:00:00
# Downloading langchain_text_splitters-0.0.1-py3-none-any.whl (21 kB)
# Downloading langsmith-0.1.51-py3-none-any.whl (115 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.0/116.0 kB 9.3 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp310-cp310-macosx_11_0_arm64.whl (14.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 64.7 MB/s eta 0:00:0031m70.8 MB/s eta 0:00:01
# Downloading pillow-10.2.0-cp310-cp310-macosx_11_0_arm64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 60.9 MB/s eta 0:00:0031m71.7 MB/s eta 0:00:01
# Downloading pydantic-2.7.1-py3-none-any.whl (409 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.3/409.3 kB 50.0 MB/s eta 0:00:00
# Downloading pydantic_core-2.18.2-cp310-cp310-macosx_11_0_arm64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 59.9 MB/s eta 0:00:00
# Downloading regex-2024.4.16-cp310-cp310-macosx_11_0_arm64.whl (291 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 291.3/291.3 kB 36.9 MB/s eta 0:00:00
# Downloading SQLAlchemy-2.0.29-cp310-cp310-macosx_11_0_arm64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 62.9 MB/s eta 0:00:00
# Downloading tenacity-8.2.3-py3-none-any.whl (24 kB)
# Downloading tqdm-4.66.2-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 9.7 MB/s eta 0:00:00
# Downloading click-8.1.7-py3-none-any.whl (97 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 kB 9.3 MB/s eta 0:00:00
# Downloading lz4-4.3.3-cp310-cp310-macosx_11_0_arm64.whl (212 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.4/212.4 kB 25.9 MB/s eta 0:00:00
# Downloading pathos-0.3.2-py3-none-any.whl (82 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 9.8 MB/s eta 0:00:00
# Downloading PyJWT-2.8.0-py3-none-any.whl (22 kB)
# Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Downloading annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Downloading botocore-1.34.69-py3-none-any.whl (12.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 64.7 MB/s eta 0:00:0031m69.6 MB/s eta 0:00:01
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 17.0 MB/s eta 0:00:00
# Downloading frozenlist-1.4.1-cp310-cp310-macosx_11_0_arm64.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.2/52.2 kB 5.0 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading marshmallow-3.21.1-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 4.9 MB/s eta 0:00:00
# Downloading multidict-6.0.5-cp310-cp310-macosx_11_0_arm64.whl (30 kB)
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 14.4 MB/s eta 0:00:00
# Downloading orjson-3.10.1-cp310-cp310-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl (250 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.6/250.6 kB 27.5 MB/s eta 0:00:00
# Downloading packaging-23.2-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 4.3 MB/s eta 0:00:00
# Downloading pox-0.3.4-py3-none-any.whl (29 kB)
# Downloading ppft-1.7.6.8-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 4.8 MB/s eta 0:00:00
# Downloading s3transfer-0.10.1-py3-none-any.whl (82 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.2/82.2 kB 7.3 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading yarl-1.9.4-cp310-cp310-macosx_11_0_arm64.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.2/79.2 kB 6.9 MB/s eta 0:00:00
# Downloading aioitertools-0.11.0-py3-none-any.whl (23 kB)
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Downloading wrapt-1.16.0-cp310-cp310-macosx_11_0_arm64.whl (38 kB)
# Building wheels for collected packages: deeplake
#   Building wheel for deeplake (pyproject.toml) ... done
#   Created wheel for deeplake: filename=deeplake-3.9.1-py3-none-any.whl size=711616 sha256=3fca1fe0f22223398fe36e4ed995ce7fd34d9e1eb9a434e86ebe2a3b0c95382b
#   Stored in directory: /Users/krzysztof/Library/Caches/pip/wheels/3b/6b/b2/05f43608fe5d959456be5da868fa80cb55dc482c62fdfb5dfe
# Successfully built deeplake
# Installing collected packages: wrapt, tqdm, tenacity, SQLAlchemy, regex, pyjwt, pydantic-core, ppft, pox, pillow, packaging, orjson, numpy, mypy-extensions, multidict, lz4, jsonpatch, jmespath, frozenlist, distro, dill, click, async-timeout, annotated-types, aioitertools, yarl, typing-inspect, tiktoken, pydantic, multiprocess, marshmallow, libdeeplake, humbug, botocore, aiosignal, s3transfer, pathos, openai, langsmith, dataclasses-json, aiohttp, langchain-core, boto3, aiobotocore, langchain-text-splitters, langchain-community, langchain, aioboto3, deeplake
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.0
#     Uninstalling packaging-24.0:
#       Successfully uninstalled packaging-24.0
# Successfully installed SQLAlchemy-2.0.29 aioboto3-12.4.0 aiobotocore-2.12.3 aiohttp-3.9.5 aioitertools-0.11.0 aiosignal-1.3.1 annotated-types-0.6.0 async-timeout-4.0.3 boto3-1.34.69 botocore-1.34.69 click-8.1.7 dataclasses-json-0.6.4 deeplake-3.9.1 dill-0.3.8 distro-1.9.0 frozenlist-1.4.1 humbug-0.3.2 jmespath-1.0.1 jsonpatch-1.33 langchain-0.1.16 langchain-community-0.0.34 langchain-core-0.1.46 langchain-text-splitters-0.0.1 langsmith-0.1.51 libdeeplake-0.0.119 lz4-4.3.3 marshmallow-3.21.1 multidict-6.0.5 multiprocess-0.70.16 mypy-extensions-1.0.0 numpy-1.26.4 openai-1.23.6 orjson-3.10.1 packaging-23.2 pathos-0.3.2 pillow-10.2.0 pox-0.3.4 ppft-1.7.6.8 pydantic-2.7.1 pydantic-core-2.18.2 pyjwt-2.8.0 regex-2024.4.16 s3transfer-0.10.1 tenacity-8.2.3 tiktoken-0.6.0 tqdm-4.66.2 typing-inspect-0.9.0 wrapt-1.16.0 yarl-1.9.4
# Requirement already satisfied: openai in /Users/krzysztof/.local/share/virtualenvs/ml-uTCkY2ki/lib/python3.10/site-packages (1.23.6)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/krzysztof/.local/share/virtualenvs/ml-uTCkY2ki/lib/python3.10/site-packages (from openai) (4.3.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/krzysztof/.local/share/virtualenvs/ml-uTCkY2ki/lib/python3.10/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/krzysztof/.local/share/virtualenvs/ml-uTCkY2ki/lib/python3.10/site-packages (from openai) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/krzysztof/.local/share/virtualenvs/ml-uTCkY2ki/lib/python3.10/site-packages (from openai) (2.7.1)
# Requirement already satisfied: sniffio in /Users/krzysztof/.local/share/virtualenvs/ml-uTCkY2ki/lib/python3.10/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/krzysztof/.local/share/virtualenvs/ml-uTCkY2ki/lib/python3.10/site-packages (from openai) (4.66.2)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /Users/krzysztof/.local/share/virtualenvs/ml-uTCkY2ki/lib/python3.10/site-packages (from openai) (4.11.0)
# Requirement already satisfied: idna>=2.8 in /Users/krzysztof/.local/share/virtualenvs/ml-uTCkY2ki/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/krzysztof/.local/share/virtualenvs/ml-uTCkY2ki/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (1.2.1)
# Requirement already satisfied: certifi in /Users/krzysztof/.local/share/virtualenvs/ml-uTCkY2ki/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /Users/krzysztof/.local/share/virtualenvs/ml-uTCkY2ki/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/krzysztof/.local/share/virtualenvs/ml-uTCkY2ki/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/krzysztof/.local/share/virtualenvs/ml-uTCkY2ki/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /Users/krzysztof/.local/share/virtualenvs/ml-uTCkY2ki/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai) (2.18.2)

# %%
import os
import getpass

from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.vectorstores import DeepLake

os.environ['OPENAI_API_KEY'] = getpass.getpass('OpenAI API Key:')
os.environ['ACTIVELOOP_TOKEN'] = getpass.getpass('Activeloop Token:')
embeddings = OpenAIEmbeddings()

import os
from langchain.document_loaders import TextLoader

root_dir = './the-algorithm'
docs = []
for dirpath, dirnames, filenames in os.walk(root_dir):
    for file in filenames:
        try:
            loader = TextLoader(os.path.join(dirpath, file), encoding='utf-8')
            docs.extend(loader.load_and_split())
        except Exception as e:
            pass

from langchain.text_splitter import CharacterTextSplitter

text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
texts = text_splitter.split_documents(docs)

db = DeepLake.from_documents(texts, embeddings, dataset_path="hub://davitbun/twitter-algorithm")

# %%
db = DeepLake(dataset_path="hub://davitbun/twitter-algorithm", read_only=True, embedding_function=embeddings)

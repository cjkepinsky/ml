# %%
from transformers import MBartForConditionalGeneration, MBart50TokenizerFast

model = MBartForConditionalGeneration.from_pretrained("facebook/mbart-large-50")
tokenizer = MBart50TokenizerFast.from_pretrained("facebook/mbart-large-50", src_lang="en_XX", tgt_lang="Cypress")

src_text = "create module loginFormModule"
tgt_text =  "export default class loginFormModule {}"

model_inputs = tokenizer(src_text, return_tensors="pt")
with tokenizer.as_target_tokenizer():
    labels = tokenizer(tgt_text, return_tensors="pt").input_ids

model(**model_inputs, labels=labels) # forward pass
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <cell line: 4>:4                                                                              │
# │                                                                                                  │
# │    1 from transformers import MBartForConditionalGeneration, MBart50TokenizerFast                │
# │    2                                                                                             │
# │    3 model = MBartForConditionalGeneration.from_pretrained("facebook/mbart-large-50")            │
# │ ❱  4 tokenizer = MBart50TokenizerFast.from_pretrained("facebook/mbart-large-50", src_lang="en    │
# │    5                                                                                             │
# │    6 src_text = "create module loginFormModule"                                                  │
# │    7 tgt_text =  "export default class loginFormModule {}"                                       │
# │                                                                                                  │
# │ /Users/kkepins-macwro_1/.pyenv/versions/3.9.13/lib/python3.9/site-packages/transformers/tokeniza │
# │ tion_utils_base.py:1801 in from_pretrained                                                       │
# │                                                                                                  │
# │   1798 │   │   │   else:                                                                         │
# │   1799 │   │   │   │   logger.info(f"loading file {file_path} from cache at {resolved_vocab_fil  │
# │   1800 │   │                                                                                     │
# │ ❱ 1801 │   │   return cls._from_pretrained(                                                      │
# │   1802 │   │   │   resolved_vocab_files,                                                         │
# │   1803 │   │   │   pretrained_model_name_or_path,                                                │
# │   1804 │   │   │   init_configuration,                                                           │
# │                                                                                                  │
# │ /Users/kkepins-macwro_1/.pyenv/versions/3.9.13/lib/python3.9/site-packages/transformers/tokeniza │
# │ tion_utils_base.py:1956 in _from_pretrained                                                      │
# │                                                                                                  │
# │   1953 │   │                                                                                     │
# │   1954 │   │   # Instantiate tokenizer.                                                          │
# │   1955 │   │   try:                                                                              │
# │ ❱ 1956 │   │   │   tokenizer = cls(*init_inputs, **init_kwargs)                                  │
# │   1957 │   │   except OSError:                                                                   │
# │   1958 │   │   │   raise OSError(                                                                │
# │   1959 │   │   │   │   "Unable to load vocabulary from file. "                                   │
# │                                                                                                  │
# │ /Users/kkepins-macwro_1/.pyenv/versions/3.9.13/lib/python3.9/site-packages/transformers/models/m │
# │ bart50/tokenization_mbart50_fast.py:135 in __init__                                              │
# │                                                                                                  │
# │   132 │   │   │   code for code in FAIRSEQ_LANGUAGE_CODES if code not in kwargs["additional_sp   │
# │   133 │   │   ]                                                                                  │
# │   134 │   │                                                                                      │
# │ ❱ 135 │   │   super().__init__(                                                                  │
# │   136 │   │   │   vocab_file,                                                                    │
# │   137 │   │   │   src_lang=src_lang,                                                             │
# │   138 │   │   │   tgt_lang=tgt_lang,                                                             │
# │                                                                                                  │
# │ /Users/kkepins-macwro_1/.pyenv/versions/3.9.13/lib/python3.9/site-packages/transformers/tokeniza │
# │ tion_utils_fast.py:120 in __init__                                                               │
# │                                                                                                  │
# │   117 │   │   │   slow_tokenizer = self.slow_tokenizer_class(*args, **kwargs)                    │
# │   118 │   │   │   fast_tokenizer = convert_slow_tokenizer(slow_tokenizer)                        │
# │   119 │   │   else:                                                                              │
# │ ❱ 120 │   │   │   raise ValueError(                                                              │
# │   121 │   │   │   │   "Couldn't instantiate the backend tokenizer from one of: \n"               │
# │   122 │   │   │   │   "(1) a `tokenizers` library serialization file, \n"                        │
# │   123 │   │   │   │   "(2) a slow tokenizer instance to convert or \n"                           │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ValueError: Couldn't instantiate the backend tokenizer from one of:
# (1) a `tokenizers` library serialization file,
# (2) a slow tokenizer instance to convert or
# (3) an equivalent slow tokenizer class to instantiate and convert.
# You need to have sentencepiece installed to convert a slow tokenizer to a fast one.
